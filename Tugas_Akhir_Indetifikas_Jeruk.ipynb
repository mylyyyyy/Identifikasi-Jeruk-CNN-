# %% [markdown]
# <a href="https://colab.research.google.com/github/mylyyyyy/Identifikasi-Jeruk-CNN-/blob/main/Tugas_Akhir_Indetifikas_Jeruk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import library
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pywt.data
from google.colab.patches import cv2_imshow

# %%
# Menyiapkan direktori kerja
import os

# Masukkan path dataset di bawah ini
path = "/content/drive/MyDrive/PCVK_Gambar/DatasetTugasAkhir/dataset orange"

os.chdir(path)
os.getcwd()

# Membuat Direktori Training dan testing
train_dir = os.path.join(path, 'Train')
test_dir = os.path.join(path, 'Test')

# membuat sub-Direktori untuk jenis jeruk dari training dan testing
# Directory training fresh orange pictures
train_fresh_dir = os.path.join(train_dir, 'freshOranges')

# Directory training rotten orange pictures
train_rotten_dir = os.path.join(train_dir, 'rottenOranges')

# Directory testing fresh orange pictures
test_fresh_dir = os.path.join(test_dir, 'freshOranges')

# Directory testing rotten orange pictures
test_rotten_dir = os.path.join(test_dir, 'rottenOranges')

# %%
# Cek nama file

train_fresh_fnames = os.listdir(train_fresh_dir)
print("Nama file fresh orange training:")
print(train_fresh_fnames[:15])

train_rotten_fnames = os.listdir(train_rotten_dir)
print("\nNama file rotten orange training:")
print(train_rotten_fnames[:15])
# Out:
# Nama file fresh orange training:
# ['rotated_by_30_Screen Shot 2018-06-13 at 12.06.43 AM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.50.28 PM.png', 'rotated_by_30_Screen Shot 2018-06-12 at 11.59.38 PM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.04.12 AM.png', 'rotated_by_30_Screen Shot 2018-06-12 at 11.56.16 PM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.03.21 AM.png', 'rotated_by_15_Screen Shot 2018-06-13 at 12.19.43 AM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.16.16 AM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.08.02 AM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.07.17 AM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.07.05 AM.png', 'rotated_by_30_Screen Shot 2018-06-12 at 11.56.48 PM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.02.20 AM.png', 'rotated_by_30_Screen Shot 2018-06-13 at 12.13.19 AM.png', 'rotated_by_30_Screen Shot 2018-06-12 at 11.56.43 PM.png']
#
# Nama file rotten orange training:
# ['rotated_by_45_Screen Shot 2018-06-12 at 11.26.07 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.25.20 PM.png', 'rotated_by_30_Screen Shot 2018-06-12 at 11.43.03 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.28.00 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.29.14 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.24.51 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.23.33 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.20.13 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.21.17 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.36.06 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.28.21 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.23.24 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.25.07 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.28.28 PM.png', 'rotated_by_45_Screen Shot 2018-06-12 at 11.35.59 PM.png']

# %%
# Menghitung banyak file input

print('\nTotal training fresh orange images:', len(train_fresh_fnames))
print('Total training rotten orange images:', len(train_rotten_fnames))
print('Total testing fresh orange images:', len(os.listdir(test_fresh_dir)))
print('Total testing rotten orange images:', len(os.listdir(test_rotten_dir)))
# Out:
# Total training fresh orange images: 1466
# Total training rotten orange images: 1605
# Total testing fresh orange images: 388
# Total testing rotten orange images: 403

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Menampilkan sampel jeruk matang dan jeruk belum matang
nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_orange_fresh_pix = [os.path.join(train_fresh_dir, fname)
                for fname in train_fresh_fnames[pic_index-8:pic_index]]
next_orange_rotten_pix = [os.path.join(train_rotten_dir, fname)
                for fname in train_rotten_fnames[pic_index-8:pic_index]]

# Menampilkan gambar dalam grid
for i, img_path in enumerate(next_orange_fresh_pix + next_orange_rotten_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# # Membangun CNN
# 1.  layer input
# 2.  3 layer convolution & pooling
# 3.  fully connected layer

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model


# Input berdimensi 150x150px dengan 3 channel untuk Blue, Green, dan Red
img_input = layers.Input(shape=(150, 150, 3))

# Convolution layer I: 16 filter berukuran 3x3
x = layers.Conv2D(16, 3, activation='relu')(img_input)
# Pooling layer: Max-pooling layer 2x2
x = layers.MaxPooling2D(2)(x)

# Convolution layer II: 32 filter berukuran 3x3
x = layers.Conv2D(32, 3, activation='relu')(x)
# Pooling layer: Max-pooling layer 2x2
x = layers.MaxPooling2D(2)(x)

# Convolution layer III: 64 filter berukuran 3x3
x = layers.Conv2D(64, 3, activation='relu')(x)
# Pooling layer: Max-pooling layer 2x2
x = layers.MaxPooling2D(2)(x)

# Fully connected layers
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid')(x)

# Menggabungkan layer input dan output
model = Model(img_input, output)

model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d_3 (Conv2D)           (None, 148, 148, 16)      448
#
#  max_pooling2d_3 (MaxPoolin  (None, 74, 74, 16)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_4 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 17, 17, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 18496)             0
#
#  dense_2 (Dense)             (None, 512)               9470464
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9494561 (36.22 MB)
# Trainable params: 9494561 (36.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Menyiapkan model untuk pelatihan dalam konteks klasifikasi biner

from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(lr=0.001),
              metrics=['acc'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
# Membuat generator data pelatihan dan validasi dari direktori gambar dengan normalisasi nilai piksel
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')

validation_generator = val_datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 3071 images belonging to 2 classes.
# Found 791 images belonging to 2 classes.

# %%
# melatih model pada dataset gambar

from tensorflow.keras.optimizers import Adam

# ...

# Membuat model
model = Model(img_input, output)

# Kompilasi model
model.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# ...

# Model fitting
history = model.fit(
    train_generator,
    steps_per_epoch=5,  # Jumlah total batch dalam satu epoch (5 kategori x 1 batch/kategori)
    epochs=15,
    validation_data=validation_generator,
    validation_steps=5,  # Jumlah total batch dalam validasi (5 kategori x 1 batch/kategori)
    verbose=2
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/15
# 5/5 - 6s - loss: 0.4503 - accuracy: 0.7987 - val_loss: 0.3385 - val_accuracy: 0.9000 - 6s/epoch - 1s/step
# Epoch 2/15
# 5/5 - 6s - loss: 0.2700 - accuracy: 0.9187 - val_loss: 0.4094 - val_accuracy: 0.8375 - 6s/epoch - 1s/step
# Epoch 3/15
# 5/5 - 5s - loss: 0.3485 - accuracy: 0.8562 - val_loss: 0.3011 - val_accuracy: 0.8750 - 5s/epoch - 1s/step
# Epoch 4/15
# 5/5 - 4s - loss: 0.3805 - accuracy: 0.8250 - val_loss: 0.3169 - val_accuracy: 0.8313 - 4s/epoch - 724ms/step
# Epoch 5/15
# 5/5 - 4s - loss: 0.2741 - accuracy: 0.9000 - val_loss: 0.3618 - val_accuracy: 0.8313 - 4s/epoch - 830ms/step
# Epoch 6/15
# 5/5 - 3s - loss: 0.3167 - accuracy: 0.8438 - val_loss: 0.3137 - val_accuracy: 0.8687 - 3s/epoch - 530ms/step
# Epoch 7/15
# 5/5 - 7s - loss: 0.3585 - accuracy: 0.8500 - val_loss: 0.3567 - val_accuracy: 0.8313 - 7s/epoch - 1s/step
# Epoch 8/15
# 5/5 - 3s - loss: 0.2401 - accuracy: 0.9062 - val_loss: 0.3338 - val_accuracy: 0.8687 - 3s/epoch - 527ms/step
# Epoch 9/15
# 5/5 - 3s - loss: 0.3717 - accuracy: 0.8500 - val_loss: 0.3306 - val_accuracy: 0.8625 - 3s/epoch - 575ms/step
# Epoch 10/15
# 5/5 - 3s - loss: 0.2957 - accuracy: 0.8750 - val_loss: 0.2631 - val_accuracy: 0.9062 - 3s/epoch - 664ms/step
# Epoch 11/15
# 5/5 - 3s - loss: 0.2891 - accuracy: 0.8938 - val_loss: 0.3364 - val_accuracy: 0.8438 - 3s/epoch - 604ms/step
# Epoch 12/15
# 5/5 - 2s - loss: 0.4013 - accuracy: 0.8188 - val_loss: 0.2986 - val_accuracy: 0.9125 - 2s/epoch - 476ms/step
# Epoch 13/15
# 5/5 - 2s - loss: 0.2922 - accuracy: 0.8813 - val_loss: 0.2965 - val_accuracy: 0.8687 - 2s/epoch - 435ms/step
# Epoch 14/15
# 5/5 - 4s - loss: 0.3006 - accuracy: 0.8687 - val_loss: 0.2699 - val_accuracy: 0.8750 - 4s/epoch - 740ms/step
# Epoch 15/15
# 5/5 - 4s - loss: 0.2092 - accuracy: 0.9250 - val_loss: 0.2980 - val_accuracy: 0.8813 - 4s/epoch - 776ms/step

# %%
# VISUALISASI AKURASI PREDIKSI

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# memvisualisasikan fitur dari setiap layer dalam model neural network
import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Mendefinisikan model untuk visualisasi
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = Model(img_input, successive_outputs)

# Memilih 1 sampel random dari setiap kategori
fresh_img_files = [os.path.join(train_fresh_dir, f) for f in os.listdir(train_fresh_dir)]
rot_img_files = [os.path.join(train_rotten_dir, f) for f in os.listdir(train_rotten_dir)]

# Gabungkan file dari kedua kategori
all_img_files = fresh_img_files + rot_img_files

# Pilih satu file secara acak
img_path = random.choice(all_img_files)
print(img_path)

# Memuat gambar dan memprosesnya untuk visualisasi
img = load_img(img_path, target_size=(150, 150))
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# Rescale 1/255
x /= 255

# Memasukkan gambar ke dalam model
successive_feature_maps = visualization_model.predict(x)

# Visualisasi fitur untuk setiap layer
layer_names = [layer.name for layer in model.layers]
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
    if len(feature_map.shape) == 4:
        n_features = feature_map.shape[-1]
        size = feature_map.shape[1]
        display_grid = np.zeros((size, size * n_features))
        for i in range(n_features):
            x = feature_map[0, :, :, i]
            x -= x.mean()
            x /= x.std()
            x *= 64
            x += 128
            x = np.clip(x, 0, 255).astype('uint8')
            display_grid[:, i * size : (i + 1) * size] = x

        scale = 20. / n_features
        plt.figure(figsize=(scale * n_features, scale))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7c48d1e9a4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /content/drive/MyDrive/PCVK_Gambar/DatasetTugasAkhir/dataset orange/Train/freshOranges/rotated_by_75_Screen Shot 2018-06-13 at 12.04.01 AM.png
# 1/1 [==============================] - 0s 79ms/step
# <ipython-input-37-7f8cbfc5321e>:41: RuntimeWarning: invalid value encountered in divide
#   x /= x.std()

# %%
# TESTING
from keras.preprocessing import image
import numpy as np

img_path=('/content/drive/MyDrive/PCVK_Gambar/DatasetTugasAkhir/dataset orange/Test/rottenOranges/Screen Shot 2018-06-12 at 11.18.34 PM.png')
img=image.load_img(img_path, target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

preds=model.predict(x)
print("Predictions",preds)

if preds[0][0] == 0:
    print("Fresh Orange")
else:
    print("Rotten Orange")
# Out:
# 1/1 [==============================] - 0s 325ms/step
# Predictions [[1.]]
# Rotten Orange

# %%
img_path=('/content/drive/MyDrive/PCVK_Gambar/DatasetTugasAkhir/dataset orange/Test/freshOranges/Screen Shot 2018-06-12 at 11.50.14 PM.png')
img=image.load_img(img_path, target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

preds=model.predict(x)
print("Predictions",preds)

if preds[0][0] == 0:
    print("Fresh Orange")
else:
    print("Rotten Orange")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Predictions [[0.]]
# Fresh Orange
